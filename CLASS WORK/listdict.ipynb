# %%
l=[
            {"name":"sid","roll":"34","sec":"A"},
            {"name":"tanu","roll":"37","sec":"B"},
            {"name":"Adi","roll":"02","sec":"A"},
            {"name":"stuty","roll":28,"sec":"A"}
]

# %%
print(l)
# Out:
# [{'name': 'sid', 'roll': '34', 'sec': 'A'}, {'name': 'tanu', 'roll': '37', 'sec': 'B'}, {'name': 'Adi', 'roll': '02', 'sec': 'A'}, {'name': 'stuty', 'roll': 28, 'sec': 'A'}]

# %%
for i in l:
    print(i)
# Out:
# {'name': 'sid', 'roll': '34', 'sec': 'A'}
# {'name': 'tanu', 'roll': '37', 'sec': 'B'}
# {'name': 'Adi', 'roll': '02', 'sec': 'A'}
# {'name': 'stuty', 'roll': 28, 'sec': 'A'}

# %%
for i in l:
    for k,j in i.items():
        print(k,j)
# Out:
# name sid
# roll 34
# sec A
# name tanu
# roll 37
# sec B
# name Adi
# roll 02
# sec A
# name stuty
# roll 28
# sec A

# %%
dict ={"sec A":[{'name':'sid',
                 'roll no':'23122034',
                 'subject':'maths',
                 'marks':'56'},
                 {'name':'tanu',
                 'roll no':'23122137',
                 'subject':'maths',
                 'marks':'98'}]
        "sec B":[{'name':'swastik',
                 'roll no':'23122138',
                 'subject':'maths',
                 'marks':'33'},
                 {'name':'vikas',
                 'roll no':'23122034',
                 'subject':'maths',
                 'marks':'56'}]

       }

# %%
pip install plotly
# Out:
# ...
#   Obtaining dependency information for plotly from https://files.pythonhosted.org/packages/df/79/c80174d711ee26ee5da55a9cc3e248f1ec7a0188b5e4d6bbbbcd09b974b0/plotly-5.17.0-py2.py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for tenacity>=6.2.0 from https://files.pythonhosted.org/packages/f4/f1/990741d5bb2487d529d20a433210ffa136a367751e454214013b441c4575/tenacity-8.2.3-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.6 MB 163.8 kB/s eta 0:01:36
# ...
