# %%
import pandas as pd

# %%
student={
    "name":['abhi','ram','sid','tanu','hitanshi','stuty','rishabh','aditya'],
    'age':[23,22,13,44,13,53,52,12]
}

# %%
print(student)
# Out:
# {'name': ['abhi', 'ram', 'sid', 'tanu', 'hitanshi', 'stuty', 'rishabh', 'aditya'], 'age': [23, 22, 13, 44, 13, 53, 52, 12]}

# %%
df=pd.DataFrame({
    "name":['abhi','ram','sid','tanu','hitanshi','stuty','rishabh','aditya'],
    'age':[23,22,13,44,13,53,52,12]
})            #store the dictionary in rows and coloumn

# %%
df.head()                   #print the top 5 value
# Out:
#        name  age
# 0      abhi   23
# 1       ram   22
# 2       sid   13
# 3      tanu   44
# 4  hitanshi   13

# %%
df.tail()           #last 5 value of rows and coloumn
# Out:
#        name  age
# 3      tanu   44
# 4  hitanshi   13
# 5     stuty   53
# 6   rishabh   52
# 7    aditya   12

# %%
print(df.head())
# Out:
#        name  age
# 0      abhi   23
# 1       ram   22
# 2       sid   13
# 3      tanu   44
# 4  hitanshi   13

# %%
df.tail(7)          #last 7 value
# Out:
#        name  age
# 1       ram   22
# 2       sid   13
# 3      tanu   44
# 4  hitanshi   13
# 5     stuty   53
# 6   rishabh   52
# 7    aditya   12

# %%
print(df.head)
# Out:
# <bound method NDFrame.head of        name  age
# 0      abhi   23
# 1       ram   22
# 2       sid   13
# 3      tanu   44
# 4  hitanshi   13
# 5     stuty   53
# 6   rishabh   52
# 7    aditya   12>

# %%
pd.read_excel("D:\EXCEL\Performing Lookups.xlsx")
# Out:
#     Unnamed: 0 Unnamed: 1          Unnamed: 2  \
# 0          NaN         ID       Employee Name
# 1          NaN        154         Paige Jones
# 2          NaN        240         Elijah Ward
# 3          NaN        319  Elizabeth Marshall
# 4          NaN        331        Cooper Smith
# 5          NaN        428     Isabella Harris
# 6          NaN        451        Kaylee Perez
# 7          NaN        527       Kimberly Hall
# 8          NaN        540         Jesus Clark
# 9          NaN        665         Kylie Woods
# 10         NaN        981    Jackson Stephens
#
#                                            Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                             Address  Frequency     Salary
# 1   427 John A. Creighton Boulevard Anytown, USA 1...         26      42900
# 2                 888 192nd Street Anytown, USA 12345         26      64600
# 3                 530 Dodge Street Anytown, USA 12345         52      72300
# ...

# %%
dd = pd.read_excel("D:\EXCEL\Performing Lookups.xlsx")

# %%
pd.read_csv('D:/github/MscDsA-MDS171-23122034-SiddharthNautiyal/lab-05/23122034.csv')
# Out:
#               grips\t4\t453\t1812
# 0       chess board\t5\t453\t2265
# 1               bat\t7\t425\t2975
# 2   badminton shoes\t4\t425\t1700
# 3            football\t4\t63\t252
# 4      cricket ball\t7\t890\t6230
# ..                            ...
# 94  badminton shoes\t7\t425\t2975
# 95         football\t4\t678\t2712
# 96         football\t5\t425\t2125
# 97              bat\t7\t425\t2975
# 98              bat\t9\t356\t3204
#
# [99 rows x 1 columns]

# %%
df2 = pd.read_csv('D:/github/MscDsA-MDS171-23122034-SiddharthNautiyal/lab-05/23122034.csv')

# %%
df2.head()
# Out:
#              grips\t4\t453\t1812
# 0      chess board\t5\t453\t2265
# 1              bat\t7\t425\t2975
# 2  badminton shoes\t4\t425\t1700
# 3           football\t4\t63\t252
# 4     cricket ball\t7\t890\t6230

# %%
df2.columns
# Out:
# Index(['grips\t4\t453\t1812'], dtype='object')

# %%
df2.describe()
# Out:
#              grips\t4\t453\t1812
# count                         99
# unique                        87
# top     basketball\t5\t425\t2125
# freq                           2

# %%
dd.describe()
# Out:
#        Unnamed: 0  Unnamed: 9  Unnamed: 10
# count         0.0         0.0          0.0
# mean          NaN         NaN          NaN
# std           NaN         NaN          NaN
# min           NaN         NaN          NaN
# 25%           NaN         NaN          NaN
# 50%           NaN         NaN          NaN
# 75%           NaN         NaN          NaN
# max           NaN         NaN          NaN

# %%
dd.memory_usage()
# Out:
# Index          132
# Unnamed: 0      88
# Unnamed: 1      88
# Unnamed: 2      88
# Unnamed: 3      88
# Unnamed: 4      88
# Unnamed: 5      88
# Unnamed: 6      88
# Unnamed: 7      88
# Unnamed: 8      88
# Unnamed: 9      88
# Unnamed: 10     88
# Unnamed: 11     88
# Unnamed: 12     88
# Unnamed: 13     88
# Unnamed: 14     88
# dtype: int64
