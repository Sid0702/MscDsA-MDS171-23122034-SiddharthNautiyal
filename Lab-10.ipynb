# %% [markdown]
# # LAB-10

# %% [markdown]
# Create a Python Class for managing student details and marks.
#
# Define the class and implement the methods of the student class in a menu-driven program for different types of users

# %%
class christ_university:    
    def __init__(self):
        self.details={}
  
    def add_details(self,name,RollNo,Department,subject):
        temp = {"Name":name,
                "RollNo":RollNo,
                "Department":Department,
                "Marks":{subject:marks}
                }
        self.details[RollNo]=temp

    def add_marks(self,regno,subject,marks):
        if regno in self.details and subject in self.details[regno]['Marks']:
            self.details[regno]["Marks"][subject] = marks
        else:
            print("Student not found")
            
    def displayStudent(self):
        for items in self.details:
            print(items)

    def update_marks(self,regno,subject,update_marks):
        if regno in self.details and subject in self.details[regno]["Marks"]:
            self.details[regno]["Marks"][subject] = update_marks
            print("Marks updated successfully")
        else:
            print("Student not found or subject not found")

    def SearchStudent(self,name):
        for regno in self.details:
            if self.details[regno]['Name'] == name:
                print(self.details[regno]['Marks']) #prints dict of marks

   # def updateStudents(self,key,value): 


        
object=christ_university()

while True:
    print("*"*30)
    print("WELCOME TO THE LAB-10")
    print("""
          Press 1 If the student access the project
          press 2 if the viewer access the project
          press 3 if the faculty access the project
          press 4 to exit the program
          """)
    print("*"*30)
    choice = int(input("Enter your choice"))
    print("Your Choice enter is:",choice)
    
    if(choice==1):
        name = input("Enter The Name")
        RollNo = input("Enter The RollNo")
        Department = input("Enter THe Department")
        subject = input("Enter The Subject")
        object.add_details(name,RollNo,Department,subject)
        object.SearchStudent(name)
    elif(choice==2):
        object.displayStudent()
    elif(choice==3):
        print("""
            Press 1 if want to access individual student details
            press 2 if want to print all the student details
            press 3 if want to enter student complete details
            press 4 if want to add the marks
            press 5 if want to update the marks
            press 6 to exit the program
            """)
        choice = int(input("enter the choice"))
        print("The Enter Choice is",choice)
        if choice==1:
            SearchStudent=input("Enter the Name to be Search")
            object.SearchStudent(SearchStudent)
        elif choice==2:
            object.displayStudent()
        elif(choice==3):
            name=input("Enter The Name to be added")
            RollNo=input("Enter The RollNo")
            Department = input("Enter THe Department")
            subject = input("Enter The Subject")
            marks = input("Enter the marks")
            object.add_details(name,RollNo,Department,subject)
            object.add_marks(RollNo,subject,marks)
            
        elif(choice==4):
            object.add_marks(RollNo,subject,marks)

        elif(choice==5):
            break

        else:
            pass
    elif choice==4:
        break
         
    else:
        print("Invalid Input")
# Out:
# ******************************
# WELCOME TO THE LAB-10
#
#           Press 1 If the student access the project
#           press 2 if the viewer access the project
#           press 3 if the faculty access the project
#           press 4 to exit the program
#
# ******************************
# Your Choice enter is: 4
